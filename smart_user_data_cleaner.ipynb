# %%
raw_data ="  AhMeT  yILMAZ ;  23 ;  1.78 ;  ahmetYILMAZ@GMAIL.Com   "

# %%
new_data_1 = raw_data.strip()

# %%
new_data_1
# Out:
# 'AhMeT  yILMAZ ;  23 ;  1.78 ;  ahmetYILMAZ@GMAIL.Com'

# %%
new_data_2 = new_data_1.split(";")

# %%
new_data_2
# Out:
# ['AhMeT  yILMAZ ', '  23 ', '  1.78 ', '  ahmetYILMAZ@GMAIL.Com']

# %%
raw_name = new_data_2[0]
raw_age = new_data_2[1]
raw_height = new_data_2[2]
raw_email = new_data_2[3]

# %%
raw_name
# Out:
# 'AhMeT  yILMAZ '

# %%
raw_name_strip = raw_name.strip()

# %%
raw_name_strip
# Out:
# 'AhMeT  yILMAZ'

# %%
raw_name_title = raw_name_strip.title()

# %%
raw_name_title
# Out:
# 'Ahmet  Yilmaz'

# %%
first_name = raw_name_title[:5]
last_name = raw_name_title[7:]

# %%
full_name = first_name + " " + last_name

# %%
full_name
# Out:
# 'Ahmet Yilmaz'

# %%
raw_age
# Out:
# '  23 '

# %%
new_age = raw_age.strip()

# %%
new_age
# Out:
# '23'

# %%
age = int(new_age)

# %%
age
# Out:
# 23

# %%
f_age = float(age)

# %%
f_age
# Out:
# 23.0

# %%
ten_years_age = f_age + 10

# %%
ten_years_age
# Out:
# 33.0

# %%
raw_height
# Out:
# '  1.78 '

# %%
raw_height_strip = raw_height.strip()

# %%
raw_height_strip
# Out:
# '1.78'

# %%
float_height = float(raw_height_strip)

# %%
float_height
# Out:
# 1.78

# %%
cm_height = float_height * 100

# %%
cm_height
# Out:
# 178.0

# %%
raw_email
# Out:
# '  ahmetYILMAZ@GMAIL.Com'

# %%
email_strip = raw_email.strip()

# %%
email_strip
# Out:
# 'ahmetYILMAZ@GMAIL.Com'

# %%
lower_email = email_strip.lower()

# %%
lower_email
# Out:
# 'ahmetyilmaz@gmail.com'

# %%
at_index = lower_email.find("@")

# %%
user_name = lower_email[:at_index]

# %%
user_name
# Out:
# 'ahmetyilmaz'

# %%
user_code = user_name[:3]

# %%
user_code
# Out:
# 'ahm'

# %%
print("Kullanıcı: " + full_name)
# Out:
# Kullanıcı: Ahmet Yilmaz

# %%
print("Yaş (10 yıl sonra): " + str(ten_years_age))
# Out:
# Yaş (10 yıl sonra): 33.0

# %%
print("Boy (cm): " + str(cm_height))
# Out:
# Boy (cm): 178.0

# %%
print("Email kullanıcı kodu: " + user_code)
# Out:
# Email kullanıcı kodu: ahm
